# %%
import tensorflow as tf

x = [1, 2, 3, 4, 5]
y = [1, 2, 3, 4, 5]

W = tf.Variable(2.9)
b = tf.Variable(0.5)

learning_rate = 0.01

for i in range(100 + 1):
    with tf.GradientTape() as tape:
        hypothesis = W * x + b
        cost = tf.reduce_mean(tf.square(hypothesis - y))
    W_grad, b_grad = tape.gradient(cost, [W, b])
    W.assign_sub(learning_rate * W_grad)
    b.assign_sub(learning_rate * b_grad)
    
    if i % 10 == 0:
        print("{:5}|{:10.4f}|{:10.4}|{:10.6f}".format(i, W.numpy(), b.numpy(), cost))
# Out:
# tf.Tensor([ 3.4       6.3       9.200001 12.1      15.      ], shape=(5,), dtype=float32)
#     0|    2.4520|     0.376| 45.660004
# tf.Tensor([ 2.828      5.28       7.7320004 10.184001  12.636001 ], shape=(5,), dtype=float32)
# tf.Tensor([ 2.39136    4.5013604  6.6113605  8.72136   10.831361 ], shape=(5,), dtype=float32)
# tf.Tensor([2.0580513 3.9069698 5.7558885 7.604807  9.453726 ], shape=(5,), dtype=float32)
# tf.Tensor([1.8036234 3.453232  5.1028404 6.752449  8.402057 ], shape=(5,), dtype=float32)
# tf.Tensor([1.6094118 3.1068656 4.604319  6.101773  7.5992265], shape=(5,), dtype=float32)
# tf.Tensor([1.4611682 2.8424647 4.223761  5.6050572 6.9863534], shape=(5,), dtype=float32)
# tf.Tensor([1.3480154 2.6406343 3.9332533 5.225872  6.518491 ], shape=(5,), dtype=float32)
# tf.Tensor([1.2616504 2.4865694 3.7114885 4.9364076 6.1613264], shape=(5,), dtype=float32)
# tf.Tensor([1.1957346 2.3689675 3.5422003 4.7154336 5.8886666], shape=(5,), dtype=float32)
# tf.Tensor([1.1454293 2.2792008 3.4129725 4.546744  5.6805153], shape=(5,), dtype=float32)
#    10|    1.1036|  0.003398|  0.206336
# tf.Tensor([1.1070406 2.2106829 3.314325  4.417968  5.5216103], shape=(5,), dtype=float32)
# tf.Tensor([1.0777489 2.158386  3.2390232 4.31966   5.400297 ], shape=(5,), dtype=float32)
# tf.Tensor([1.0554016 2.1184716 3.1815417 4.244612  5.3076825], shape=(5,), dtype=float32)
# tf.Tensor([1.0383554 2.08801   3.1376648 4.1873198 5.2369747], shape=(5,), dtype=float32)
# tf.Tensor([1.025356  2.0647647 3.1041737 4.1435823 5.182991 ], shape=(5,), dtype=float32)
# tf.Tensor([1.0154457 2.0470278 3.07861   4.110192  5.1417737], shape=(5,), dtype=float32)
# tf.Tensor([1.0078937 2.0334957 3.0590978 4.0847    5.1103024], shape=(5,), dtype=float32)
# tf.Tensor([1.0021417 2.0231738 3.044206  4.065238  5.0862703], shape=(5,), dtype=float32)
# tf.Tensor([0.9977639 2.0153024 3.0328407 4.0503793 5.067918 ], shape=(5,), dtype=float32)
# tf.Tensor([0.9944351 2.0093017 3.0241683 4.0390344 5.0539007], shape=(5,), dtype=float32)
#    20|    1.0128|  -0.02091|  0.001026
# tf.Tensor([0.99190706 2.0047288  3.0175507  4.0303726  5.0431943 ], shape=(5,), dtype=float32)
# tf.Tensor([0.9899901 2.001246  3.012502  4.023758  5.0350137], shape=(5,), dtype=float32)
# tf.Tensor([0.98853976 1.9985954  3.0086508  4.0187063  5.028762  ], shape=(5,), dtype=float32)
# tf.Tensor([0.9874455 1.9965798 3.0057142 4.014848  5.0239825], shape=(5,), dtype=float32)
# tf.Tensor([0.986623  1.9950491 3.003475  4.0119014 5.0203276], shape=(5,), dtype=float32)
# tf.Tensor([0.986008  1.9938885 3.001769  4.0096498 5.0175304], shape=(5,), dtype=float32)
# tf.Tensor([0.9855512 1.9930104 3.0004694 4.007929  5.015388 ], shape=(5,), dtype=float32)
# tf.Tensor([0.9852153 1.992348  2.9994807 4.0066133 5.013746 ], shape=(5,), dtype=float32)
# tf.Tensor([0.9849715 1.99185   2.9987288 4.005607  5.0124855], shape=(5,), dtype=float32)
# tf.Tensor([0.98479813 1.9914777  2.9981575  4.004837   5.0115166 ], shape=(5,), dtype=float32)
#    30|    1.0065|  -0.02184|  0.000093
# tf.Tensor([0.9846783 1.9912013 2.9977243 4.004247  5.0107703], shape=(5,), dtype=float32)
# tf.Tensor([0.98459953 1.9909981  2.997397   4.0037956  5.0101943 ], shape=(5,), dtype=float32)
# tf.Tensor([0.9845518 1.9908507 2.9971495 4.0034485 5.0097475], shape=(5,), dtype=float32)
# tf.Tensor([0.9845278 1.9907458 2.9969637 4.003182  5.0094   ], shape=(5,), dtype=float32)
# tf.Tensor([0.98452204 1.9906735  2.996825   4.0029764  5.0091276 ], shape=(5,), dtype=float32)
# tf.Tensor([0.98453003 1.9906259  2.9967217  4.0028176  5.0089135 ], shape=(5,), dtype=float32)
# tf.Tensor([0.9845485 1.9905972 2.9966462 4.002695  5.008744 ], shape=(5,), dtype=float32)
# tf.Tensor([0.9845748 1.9905828 2.9965906 4.002599  5.008607 ], shape=(5,), dtype=float32)
# tf.Tensor([0.9846072 1.9905795 2.9965515 4.002524  5.0084963], shape=(5,), dtype=float32)
# tf.Tensor([0.98464423 1.9905845  2.9965248  4.0024652  5.0084057 ], shape=(5,), dtype=float32)
#    40|    1.0059|  -0.02123|  0.000083
# tf.Tensor([0.98468465 1.9905959  2.996507   4.0024185  5.00833   ], shape=(5,), dtype=float32)
# tf.Tensor([0.98472756 1.9906119  2.9964962  4.0023804  5.0082645 ], shape=(5,), dtype=float32)
# tf.Tensor([0.9847725 1.9906316 2.9964907 4.00235   5.008209 ], shape=(5,), dtype=float32)
# tf.Tensor([0.9848188 1.9906541 2.9964895 4.0023246 5.00816  ], shape=(5,), dtype=float32)
# tf.Tensor([0.98486626 1.9906788  2.9964912  4.002304   5.0081167 ], shape=(5,), dtype=float32)
# tf.Tensor([0.9849145 1.9907051 2.9964955 4.0022864 5.008077 ], shape=(5,), dtype=float32)
# tf.Tensor([0.98496324 1.9907326  2.9965017  4.002271   5.0080404 ], shape=(5,), dtype=float32)
# tf.Tensor([0.98501235 1.9907608  2.9965093  4.0022573  5.0080056 ], shape=(5,), dtype=float32)
# tf.Tensor([0.98506165 1.9907895  2.9965177  4.0022454  5.007973  ], shape=(5,), dtype=float32)
# tf.Tensor([0.9851112 1.9908189 2.9965267 4.0022345 5.007942 ], shape=(5,), dtype=float32)
#    50|    1.0057|  -0.02053|  0.000077
# tf.Tensor([0.9851607 1.9908485 2.9965365 4.0022244 5.007912 ], shape=(5,), dtype=float32)
# tf.Tensor([0.98521036 1.9908785  2.9965467  4.002215   5.007883  ], shape=(5,), dtype=float32)
# tf.Tensor([0.98525983 1.9909085  2.996557   4.002206   5.0078545 ], shape=(5,), dtype=float32)
# tf.Tensor([0.9853093 1.9909384 2.9965677 4.002197  5.007826 ], shape=(5,), dtype=float32)
# tf.Tensor([0.9853587 1.9909687 2.9965787 4.0021887 5.0077987], shape=(5,), dtype=float32)
# tf.Tensor([0.98540807 1.990999   2.99659    4.002181   5.007772  ], shape=(5,), dtype=float32)
# tf.Tensor([0.9854572 1.991029  2.9966009 4.002173  5.007745 ], shape=(5,), dtype=float32)
# tf.Tensor([0.98550624 1.9910591  2.996612   4.002165   5.0077176 ], shape=(5,), dtype=float32)
# tf.Tensor([0.9855552 1.9910892 2.996623  4.002157  5.0076914], shape=(5,), dtype=float32)
# tf.Tensor([0.985604  1.9911193 2.9966347 4.00215   5.007665 ], shape=(5,), dtype=float32)
#    60|    1.0055|  -0.01984|  0.000072
# tf.Tensor([0.98565257 1.9911492  2.996646   4.0021424  5.007639  ], shape=(5,), dtype=float32)
# tf.Tensor([0.9857011 1.9911791 2.9966571 4.0021353 5.007613 ], shape=(5,), dtype=float32)
# tf.Tensor([0.9857493 1.9912088 2.9966683 4.0021276 5.007587 ], shape=(5,), dtype=float32)
# tf.Tensor([0.98579746 1.9912385  2.9966793  4.0021205  5.007561  ], shape=(5,), dtype=float32)
# tf.Tensor([0.9858455 1.9912682 2.9966908 4.0021133 5.007536 ], shape=(5,), dtype=float32)
# tf.Tensor([0.98589337 1.9912976  2.9967017  4.002106   5.0075107 ], shape=(5,), dtype=float32)
# tf.Tensor([0.9859411 1.991327  2.9967132 4.002099  5.007485 ], shape=(5,), dtype=float32)
# tf.Tensor([0.98598856 1.9913564  2.9967241  4.002092   5.0074596 ], shape=(5,), dtype=float32)
# tf.Tensor([0.986036  1.9913856 2.9967353 4.0020847 5.0074344], shape=(5,), dtype=float32)
# tf.Tensor([0.98608315 1.9914147  2.9967463  4.0020776  5.007409  ], shape=(5,), dtype=float32)
#    70|    1.0053|  -0.01918|  0.000067
# tf.Tensor([0.98613024 1.9914438  2.9967573  4.002071   5.0073843 ], shape=(5,), dtype=float32)
# tf.Tensor([0.9861771 1.9914726 2.996768  4.0020638 5.0073595], shape=(5,), dtype=float32)
# tf.Tensor([0.9862238 1.9915015 2.9967792 4.0020566 5.007334 ], shape=(5,), dtype=float32)
# tf.Tensor([0.98627037 1.9915302  2.99679    4.0020494  5.007309  ], shape=(5,), dtype=float32)
# tf.Tensor([0.9863168 1.9915588 2.996801  4.002043  5.0072846], shape=(5,), dtype=float32)
# tf.Tensor([0.98636305 1.9915873  2.9968114  4.0020356  5.00726   ], shape=(5,), dtype=float32)
# tf.Tensor([0.9864092 1.9916158 2.9968224 4.002029  5.0072355], shape=(5,), dtype=float32)
# tf.Tensor([0.9864551 1.991644  2.9968328 4.002022  5.0072107], shape=(5,), dtype=float32)
# tf.Tensor([0.9865009 1.9916723 2.9968438 4.002015  5.0071864], shape=(5,), dtype=float32)
# tf.Tensor([0.9865465 1.9917004 2.9968543 4.002008  5.0071616], shape=(5,), dtype=float32)
#    80|    1.0051|  -0.01854|  0.000063
# tf.Tensor([0.986592  1.9917285 2.996865  4.0020013 5.007138 ], shape=(5,), dtype=float32)
# tf.Tensor([0.9866373 1.9917564 2.9968755 4.0019946 5.007114 ], shape=(5,), dtype=float32)
# tf.Tensor([0.98668253 1.9917843  2.9968863  4.001988   5.0070896 ], shape=(5,), dtype=float32)
# tf.Tensor([0.98672754 1.991812   2.9968965  4.0019813  5.007066  ], shape=(5,), dtype=float32)
# tf.Tensor([0.9867724 1.9918398 2.996907  4.0019746 5.007042 ], shape=(5,), dtype=float32)
# tf.Tensor([0.9868171 1.9918673 2.9969175 4.0019674 5.0070176], shape=(5,), dtype=float32)
# tf.Tensor([0.9868617 1.9918948 2.996928  4.001961  5.0069942], shape=(5,), dtype=float32)
# tf.Tensor([0.9869061 1.9919221 2.9969382 4.0019546 5.006971 ], shape=(5,), dtype=float32)
# tf.Tensor([0.9869504 1.9919496 2.9969487 4.001948  5.006947 ], shape=(5,), dtype=float32)
# tf.Tensor([0.9869945 1.9919767 2.996959  4.001941  5.006923 ], shape=(5,), dtype=float32)
#    90|    1.0050|  -0.01793|  0.000059
# tf.Tensor([0.9870385 1.9920039 2.9969695 4.001935  5.0069003], shape=(5,), dtype=float32)
# tf.Tensor([0.9870823 1.992031  2.9969795 4.0019283 5.006877 ], shape=(5,), dtype=float32)
# tf.Tensor([0.98712605 1.9920579  2.99699    4.0019217  5.0068536 ], shape=(5,), dtype=float32)
# tf.Tensor([0.98716956 1.9920847  2.997      4.0019155  5.0068307 ], shape=(5,), dtype=float32)
# tf.Tensor([0.98721296 1.9921117  2.9970105  4.001909   5.0068073 ], shape=(5,), dtype=float32)
# tf.Tensor([0.98725617 1.9921383  2.9970205  4.0019026  5.0067844 ], shape=(5,), dtype=float32)
# tf.Tensor([0.9872993 1.992165  2.9970307 4.0018964 5.006762 ], shape=(5,), dtype=float32)
# tf.Tensor([0.9873423 1.9921914 2.9970407 4.0018897 5.006739 ], shape=(5,), dtype=float32)
# tf.Tensor([0.98738503 1.9922178  2.9970505  4.001883   5.006716  ], shape=(5,), dtype=float32)
# tf.Tensor([0.98742765 1.9922441  2.9970603  4.001877   5.0066934 ], shape=(5,), dtype=float32)
#   100|    1.0048|  -0.01733|  0.000055
